# %%
from numpy.linalg import inv
import numpy as np
import matplotlib.pyplot as plt
import math
import sympy
from sympy import *
from IPython.display import display, HTML
import random

# %matplotlib inline
# %config IPCompleter.greedy=True
sympy.init_printing(use_unicode=False, wrap_line=True)
np.set_printoptions(suppress=True)

def CLT_std_norm_rand():
    random_nums = [random.uniform(0, 1) for x in range(12)] 
    std_norm_rand = sum(random_nums) - 6
    return std_norm_rand

def gaussian_data_generator(mean, var, method=0):
    if method==0:
        std_norm_rand = CLT_std_norm_rand()
    norm_rand = mean + (std_norm_rand * var**(1/2))
    return norm_rand

def plot_data(D1, D2):
    xs_1 = [x for x,y,b in D1]
    ys_1 = [y for x,y,b in D1]
    xs_2 = [x for x,y,b in D2]
    ys_2 = [y for x,y,b in D2]
    plt.scatter(xs_1, ys_1, color='blue', marker='o')
    plt.scatter(xs_2, ys_2, color='red', marker='o')
    
    # plt.show()

def plot_decision_boundary(theta):
    w1, w2, w0 = theta
    xs = np.linspace(-10, 10, 100)
    ys = [ np.asscalar((-w0-w1*x1)/w2) for x1 in xs]
    
    plt.plot(xs, ys, label='Decision Boundary')
    ys_upper = [ y+1000 for y in ys]
    ys_lower = [ y-1000 for y in ys]
    
    plt.plot(xs, ys_upper, c = "g")
    plt.plot(xs, ys_lower, c = 'r')

    plt.fill_between(xs, ys, ys_upper, facecolor = "red", alpha=0.1)
    plt.fill_between(xs, ys, ys_lower, facecolor = "blue", alpha=0.1)
    #plt.legend()

# %%
def logistic_function(z):
    e = math.e
    return 1 / (1 + e**(-z) )

def prediction(x, w):
    z = np.asscalar(np.matmul(w.T, x))
    return logistic_function(z)

def evaluation(X,Y,theta):
    n_correct, n_total = 0, 0
    for x, y in zip(X,Y):
        x_ = np.array(x, ndmin=2).reshape(num_basis, 1)
        pred = prediction(x_, theta)
        if int(pred>=0.5) == y:
            n_correct += 1
        n_total += 1
    return n_correct / n_total

# ###################################
# ### Stochastic Gradient Descent ###
# ###################################
# def stochastic_gradient_descent(X, Y, theta, learning_rate=0.01, max_epoch=10):
#     '''
#     X  = Data Points [(x1,y1), (x2, y2), ...]
#     y  = Labels [1, 0, 1, ...]
#     theta = Vector of init thetas 
#     '''
#     order = [i for i in range(len(X))]
#     order = np.random.permutation(order)
    
#     for epoch in range(max_epoch):
#         for i in order:
#             x = np.array(X[i], ndmin=2).reshape(num_basis, 1)
#             y = Y[i]
#             pred = prediction(x, theta)
#             theta = theta - learning_rate * x * (pred-y)
#         order = np.random.permutation(order)
#     return theta

# ###################################
# ### Mini-batch Gradient Descent ###
# ###################################
# def minibatch_gradient_descent(X, Y, theta, learning_rate=0.01, max_epoch=10, batch_size=10):
#     '''
#     X  = Data Points [(x1,y1), (x2, y2), ...]
#     y  = Labels [1, 0, 1, ...]
#     theta = Vector of init thetas 
#     '''
#     order = [i for i in range(len(X))]
#     order = np.random.permutation(order)
    
#     for epoch in range(max_epoch):
#         gradient = np.zeros(theta.shape)
#         for cnt, i in enumerate(order):
#             x = np.array(X[i], ndmin=2).reshape(num_basis, 1)
#             y = Y[i]
#             pred = prediction(x, theta)
#             gradient += x * (pred-y)
#             if (cnt+1) % batch_size == 0:
#                 gradient /= batch_size
#                 theta = theta - learning_rate * gradient
#                 gradient = np.zeros(theta.shape)
#         order = np.random.permutation(order)
#     return theta

# %%
# Ground Truth
mx1 = 0
my1 = 0
vx1 = 0.1
vy1 = 0.1

mx2 = 0.2
my2 = 0.8
vx2 = 0.1
vy2 = 0.1

# Generate Data
num_points = 1000
D1 = []
D2 = []
for i in range(num_points):
    x1 = gaussian_data_generator(mean=mx1, var=vx1)
    y1 = gaussian_data_generator(mean=my1, var=vy1)
    D1.append([x1, y1, 1]) # add bais term
    x2 = gaussian_data_generator(mean=mx2, var=vx2)
    y2 = gaussian_data_generator(mean=my2, var=vy2)
    D2.append([x2, y2, 1]) # add bias term

# %%
# w = [0, 0, 0]
# num_basis = len(w)
# theta = np.array(w, ndmin=2).reshape(num_basis, 1)

# X = [point for point in D1] + [point for point in D2]
# Y = [0 for i in range(len(D1))] + [1 for i in range(len(D2))]

# max_epoch = 100
# theta_GD  = minibatch_gradient_descent(X, Y, theta, learning_rate=0.01, max_epoch=100, batch_size=num_points)
# theta_SGD = minibatch_gradient_descent(X, Y, theta, learning_rate=0.001, max_epoch=100, batch_size=1)
# theta_min = minibatch_gradient_descent(X, Y, theta, learning_rate=0.01, max_epoch=100, batch_size=10)


# print('After %d epochs'%max_epoch)
# plt.figure(figsize=(10,10))


# plt.subplot(221)
# plt.title('Ground Truth')
# plot_data(D1, D2)
# plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
# plt.xlim(np.min(X)-0.1, np.max(X)+0.1)

# #plt.figure(figsize=(5,5))
# plt.subplot(222)
# plt.title('Whole batch (acc : %.2f)'%(evaluation(X,Y,theta_GD)*100))
# plot_data(D1, D2)
# plot_decision_boundary(theta_GD)
# plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
# plt.xlim(np.min(X)-0.1, np.max(X)+0.1)


# #plt.figure(figsize=(10,3))
# plt.subplot(223)
# plt.title('SGD (acc : %.2f)'% (evaluation(X,Y,theta_SGD)*100))
# plot_data(D1, D2)
# plot_decision_boundary(theta_SGD)
# plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
# plt.xlim(np.min(X)-0.1, np.max(X)+0.1)

# #plt.figure(figsize=(10,3))
# plt.subplot(224)
# plt.title('mini-batch (acc : %.2f)'% (evaluation(X,Y,theta_min)*100))
# plot_data(D1, D2)
# plot_decision_boundary(theta_min)
# plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
# plt.xlim(np.min(X)-0.1, np.max(X)+0.1)
# plt.show()

# %%
#########################
###  Newton's Method  ###
#########################
from math import e
from math import log
from numpy import linalg
import sys

def hession(X, w):
    D = np.zeros((len(X), len(X)))
    for d in range(len(X)):
        x = np.array(X[d], ndmin=2).reshape(num_basis, 1)
        z = np.asscalar(np.matmul(w.T, x))
        D[d][d] = e**(-z) / ((1+e**(-z))**2)
    A = np.array(X)
    return np.matmul(np.matmul(A.T, D), A)

def gradient(X, Y, theta):
    predictions = []
    for x in X:
        x = np.array(x, ndmin=2).reshape(num_basis, 1)
        predictions.append(prediction(x, theta))
    X = np.reshape(X, (len(X), 3))
    Y = np.reshape(Y, (len(Y), 1))
    predictions = np.reshape(predictions, (len(Y), 1))
    return np.matmul(X.T, predictions-Y)

def compute_loss(X, Y, theta):
    loss = 0
    for x, y in zip(X,Y):
        y_pred = prediction(x, theta)
        loss += -1*(y*log(y_pred) + (1-y)*log(1-y_pred))
    return loss / len(X)
        
    
def logistic_optimization(X, Y, theta, lr=0.1, max_epochs=10, batch_size=100):
    X = np.array(X)
    Y = np.array(Y)
    best_loss = 100
    for epoch in range(max_epochs):
        print('#### epoch : %d ####:' %(epoch+1))
        order = [i for i in range(len(X))]
        order = np.random.permutation(order)
        for i in range(0, len(order), batch_size):
            indexes = order[i:i+batch_size] if i+batch_size < len(order) else order[i:]
            X_sample = X[indexes]
            Y_sample = Y[indexes]
            h = hession(X_sample, theta)
            g = gradient(X_sample, Y_sample, theta)
            if linalg.cond(h) < 1/sys.float_info.epsilon: 
                # if hession is invertible, use newton's method
                h_inv = linalg.inv(h)
                theta = theta - lr * np.matmul(h_inv, g)
            else:
                # if hession is not invertible, use gradient descent
                theta = theta - lr * g
        loss = compute_loss(X, Y, theta)
        print('Loss : %.8f'% (loss))
        print('Acc : %.2f'% (evaluation(X,Y,theta)*100))
        if loss >= best_loss:
            print('\nConverge after %d epoch' %(epoch+1))
            break
        else:
            best_loss = loss
    return theta
    
w = [0, 0, 0]
num_basis = len(w)
theta = np.array(w, ndmin=2).reshape(num_basis, 1)

X = [point for point in D1] + [point for point in D2]
Y = [0 for i in range(len(D1))] + [1 for i in range(len(D2))]

h = hession(X, theta)
theta_newton = logistic_optimization(X, Y, theta, max_epochs=100, batch_size=1000)
# Out:
# #### epoch : 1 ####:
# Loss : 0.58465003
# Acc : 90.50
# #### epoch : 2 ####:
# Loss : 0.50804071
# Acc : 90.50
# #### epoch : 3 ####:
# Loss : 0.45039879
# Acc : 90.55
# #### epoch : 4 ####:
# Loss : 0.40547280
# Acc : 90.55
# #### epoch : 5 ####:
# Loss : 0.36979723
# Acc : 90.60
# #### epoch : 6 ####:
# Loss : 0.34125578
# Acc : 90.65
# #### epoch : 7 ####:
# Loss : 0.31818902
# Acc : 90.65
# #### epoch : 8 ####:
# Loss : 0.29973072
# Acc : 90.65
# #### epoch : 9 ####:
# Loss : 0.28485168
# Acc : 90.70
# #### epoch : 10 ####:
# Loss : 0.27301463
# Acc : 90.70
# #### epoch : 11 ####:
# Loss : 0.26359797
# Acc : 90.70
# #### epoch : 12 ####:
# Loss : 0.25621615
# Acc : 90.75
# #### epoch : 13 ####:
# Loss : 0.25043632
# Acc : 90.75
# #### epoch : 14 ####:
# Loss : 0.24610010
# Acc : 90.75
# #### epoch : 15 ####:
# Loss : 0.24279746
# Acc : 90.70
# #### epoch : 16 ####:
# Loss : 0.24033508
# Acc : 90.70
# #### epoch : 17 ####:
# Loss : 0.23851281
# Acc : 90.70
# #### epoch : 18 ####:
# Loss : 0.23719009
# Acc : 90.70
# #### epoch : 19 ####:
# Loss : 0.23626737
# Acc : 90.70
# #### epoch : 20 ####:
# Loss : 0.23564164
# Acc : 90.75
# #### epoch : 21 ####:
# Loss : 0.23515321
# Acc : 90.75
# #### epoch : 22 ####:
# Loss : 0.23482546
# Acc : 90.80
# #### epoch : 23 ####:
# Loss : 0.23460046
# Acc : 90.80
# #### epoch : 24 ####:
# Loss : 0.23444754
# Acc : 90.80
# #### epoch : 25 ####:
# Loss : 0.23434037
# Acc : 90.80
# #### epoch : 26 ####:
# Loss : 0.23427055
# Acc : 90.80
# #### epoch : 27 ####:
# Loss : 0.23423136
# Acc : 90.75
# #### epoch : 28 ####:
# Loss : 0.23419623
# Acc : 90.75
# #### epoch : 29 ####:
# Loss : 0.23417374
# Acc : 90.75
# #### epoch : 30 ####:
# Loss : 0.23415796
# Acc : 90.75
# #### epoch : 31 ####:
# Loss : 0.23415011
# Acc : 90.75
# #### epoch : 32 ####:
# Loss : 0.23414109
# Acc : 90.75
# #### epoch : 33 ####:
# Loss : 0.23413724
# Acc : 90.75
# #### epoch : 34 ####:
# Loss : 0.23413483
# Acc : 90.80
# #### epoch : 35 ####:
# Loss : 0.23413325
# Acc : 90.80
# #### epoch : 36 ####:
# Loss : 0.23413099
# Acc : 90.80
# #### epoch : 37 ####:
# Loss : 0.23412980
# Acc : 90.80
# #### epoch : 38 ####:
# Loss : 0.23413017
# Acc : 90.80
#
# Converge after 38 epoch

# %%
print('Loss : %.2f'% (compute_loss(X, Y, theta_newton)))
print('Acc : %.2f'% (evaluation(X,Y,theta_newton)*100))
plt.figure(figsize=(10,5))

plt.subplot(121)
plt.title('Ground Truth')
plot_data(D1, D2)
plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
plt.xlim(np.min(X)-0.1, np.max(X)+0.1)

plt.subplot(122)
plt.title('Prediction (Acc : %.2f%%)'%(evaluation(X,Y,theta_newton)*100))
plot_data(D1, D2
          
          
plot_decision_boundary(theta_newton)
plt.ylim(np.min(X)-0.1, np.max(X)+0.1)
plt.xlim(np.min(X)-0.1, np.max(X)+0.1)
plt.show()
# Out:
# Loss : 0.23
# Acc : 90.80
